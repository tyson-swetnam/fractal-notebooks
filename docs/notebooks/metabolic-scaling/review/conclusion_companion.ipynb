# %% [markdown]
# # Conclusion — what would have to be true, and a decision table
#
# *Companion to Part II — Metabolic Scaling Theory and Biological Fractals.* CC-BY-4.0. This is a **reviewer's** notebook: it exists to test the paper's claims, not just to illustrate them.
#
# The Conclusion says 'We reaffirm the predictions of MST.' A referee asks: *reaffirm on what evidence?* This notebook turns the conclusions into a checklist a revision can drive to green.

# %%
import sys, os
HERE = os.getcwd()
if HERE not in sys.path:
    sys.path.insert(0, HERE)
# fractal_review_utils.py lives next to these notebooks. Launch Jupyter from
# docs/notebooks/metabolic-scaling/review/ (or add that folder to sys.path).
import numpy as np
import matplotlib.pyplot as plt
import fractal_review_utils as u
print('utils loaded from', u.__file__)
# Out:
# utils loaded from /Users/tswetnam/github/fractal-notebooks/docs/notebooks/metabolic-scaling/review/fractal_review_utils.py

# %% [markdown]
# ## Decision table — each conclusion vs. the evidence needed

# %%
rows = [
  ('C1 natural fractals are self-affine',
   'measure a known self-affine object with both methods; show self-similar is biased',
   'introduction_companion'),
  ('C2 1/f^beta noises describe organism dimensions',
   'fit power spectra of the real images; report beta and derived D with CIs',
   'results_companion (+ add PSD)'),
  ('C3 mechanism is entropy maximization',
   'state an observable that could be inconsistent with MEP',
   'discussion_companion'),
  ('C4 MST predictions reaffirmed',
   'pick ONE target (3, 3/2, or 4/3); TOST equivalence at a margin that separates them',
   'methods_ + results_companion'),
]
for c, need, nb in rows:
    print(f'* {c}\n    evidence needed : {need}\n    notebook        : {nb}\n')
# Out:
# * C1 natural fractals are self-affine
#     evidence needed : measure a known self-affine object with both methods; show self-similar is biased
#     notebook        : introduction_companion
#
# * C2 1/f^beta noises describe organism dimensions
#     evidence needed : fit power spectra of the real images; report beta and derived D with CIs
#     notebook        : results_companion (+ add PSD)
#
# * C3 mechanism is entropy maximization
#     evidence needed : state an observable that could be inconsistent with MEP
#     notebook        : discussion_companion
#
# * C4 MST predictions reaffirmed
#     evidence needed : pick ONE target (3, 3/2, or 4/3); TOST equivalence at a margin that separates them
#     notebook        : methods_ + results_companion

# %%
# A single number that summarizes the current gap: can the study separate 3/2 from 4/3?
sep = abs(1.5 - 4/3)
print(f'|3/2 - 4/3| = {sep:.3f}. To claim 3/2 over 4/3, the equivalence margin must be')
print(f'< {sep/2:.3f}. The Results use spreads (SD up to 0.08) and n as low as 3, so the')
print('study currently cannot resolve its own two competing predictions.')
# Out:
# |3/2 - 4/3| = 0.167. To claim 3/2 over 4/3, the equivalence margin must be
# < 0.083. The Results use spreads (SD up to 0.08) and n as low as 3, so the
# study currently cannot resolve its own two competing predictions.

# %% [markdown]
# ### Bottom line
# The conclusions are reachable, but the manuscript has not yet earned them. The fastest path to a defensible paper: (1) fix the derivation and pick one target; (2) add the known-D control; (3) replace 'indistinguishable' with a TOST at a discriminating margin.
